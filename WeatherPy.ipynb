# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
coordinates
# Out:
# [(-87.0711629535153, 40.64963665205775),
#  (68.78891343565206, -94.19591862684393),
#  (21.839802727486003, -144.75269621334579),
#  (82.17179322376052, 128.25645198654564),
#  (65.45499451003911, 143.4731700133043),
#  (58.03376011104595, 57.071735609594754),
#  (33.730852229323474, -101.853831634134),
#  (-29.782045281122095, 72.07363882414896),
#  (-10.13360343287313, -51.2597436723901),
#  (4.170304985198982, -34.59130483723811),
#  (-71.79860338438196, 48.57769983490084),
#  (58.24312563539513, -135.83272904851273),
#  (67.15873310218493, 51.412878679985226),
#  (-35.59772141981538, -41.88821731670711),
#  (-52.89466553115978, 93.9831171959687),
#  (-64.27439038055002, -118.53435828475486),
#  (48.69940888932436, -89.05172176694546),
#  (85.19769200437193, -62.604760866404376),
#  (-13.63466300306014, -82.91949945055988),
#  (-6.223258251371746, 114.59290191263523),
#  (-16.746213104733272, -39.87261783481637),
#  (0.1478154234269624, -116.66334961678122),
# ...

# %%
#pip install citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
import requests
requests.__version__
# Out:
# '2.27.1'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Config weather api key is a safety procosion - just in case the script is leaked, your api key isnt

# %%
weather_api_key == "e52763fce3c9071965e25df476735e27"
# Out:
# True

# %%
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Shows nothing because there isnt a city
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e52763fce3c9071965e25df476735e27

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e52763fce3c9071965e25df476735e27&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Shows us what code we have - because its not a 404, we know at least that its accessing a
# valid website - we just can access the content
# Out:
# 200

# %%
city_weather.text
# Because we can see that the text is a dictionary of dictionaries - this indicates that this is in 
# json format
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}],"base":"stations","main":{"temp":18.45,"feels_like":5.85,"temp_min":16.29,"temp_max":20.23,"pressure":1013,"humidity":55},"visibility":10000,"wind":{"speed":25.01,"deg":0,"gust":27},"clouds":{"all":20},"dt":1648537924,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1648549908,"sunset":1648595155},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
city_weather.json()
# Helps to see the overall structure of the data
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 18.45,
#   'feels_like': 5.85,
#   'temp_min': 16.29,
#   'temp_max': 20.23,
#   'pressure': 1013,
#   'humidity': 55},
#  'visibility': 10000,
#  'wind': {'speed': 25.01, 'deg': 0, 'gust': 27},
#  'clouds': {'all': 20},
#  'dt': 1648537924,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648549908,
#   'sunset': 1648595155},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
x = city_weather.json()
x
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 18.45,
#   'feels_like': 5.85,
#   'temp_min': 16.29,
#   'temp_max': 20.23,
#   'pressure': 1013,
#   'humidity': 55},
#  'visibility': 10000,
#  'wind': {'speed': 25.01, 'deg': 0, 'gust': 27},
#  'clouds': {'all': 20},
#  'dt': 1648537924,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648549908,
#   'sunset': 1648595155},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
x['weather'][0]['description']
# Out:
# 'few clouds'

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
    

# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)

# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'},
#   {'id': 300,
#    'main': 'Drizzle',
#    'description': 'light intensity drizzle',
#    'icon': '09n'}],
#  'base': 'stations',
#  'main': {'temp': 42.49,
#   'feels_like': 35.02,
#   'temp_min': 39.97,
#   'temp_max': 45.1,
#   'pressure': 1011,
#   'humidity': 95},
#  'visibility': 1207,
#  'wind': {'speed': 15.01, 'deg': 0, 'gust': 0},
#  'clouds': {'all': 100},
#  'dt': 1648170619,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648118433,
#   'sunset': 1648162819},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1648118433,
#  'sunset': 1648162819}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data['dt'] #The date in the weather data
# Out:
# 1648170619

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 45.1 95 100 15.01

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 3, 25, 1, 10, 19)

# %%
# Formatting the datetime to a more reasonable form
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-03-25 01:10:19'

# %%
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
cities
# Out:
# ['port elizabeth',
#  'lagos',
#  'severo-kurilsk',
#  'kyabe',
#  'busselton',
#  'nemuro',
#  'iqaluit',
#  'ixtapa',
#  'puerto ayora',
#  'bisert',
#  'avarua',
#  'cabanas',
#  'vaitupu',
#  'buraydah',
#  'hermanus',
#  'butaritari',
#  'dallas',
#  'beihai',
#  'khatanga',
#  'te anau',
#  'charlestown',
#  'haines junction',
#  'itarema',
#  'luderitz',
#  'japura',
#  'leningradskiy',
#  'lebu',
#  'nikolskoye',
#  'ponta do sol',
#  'ushuaia',
#  'laizhou',
#  'svetlaya',
#  'san patricio',
#  'san joaquin',
#  'lasa',
#  'kupang',
#  'margate',
#  'kodiak',
#  'necocli',
#  'rikitea',
#  'kavieng',
#  'katihar',
#  'finnsnes',
#  'tsihombe',
#  'lompoc',
#  'kudahuvadhoo',
#  'khuzdar',
#  'faanui',
#  'mataura',
#  'san policarpo',
#  'punta arenas',
#  'sangar',
#  'east london',
#  'tuktoyaktuk',
#  'yellowknife',
#  'bambous virieux',
#  'samusu',
#  'jamestown',
#  'kimbe',
#  'georgetown',
#  'tasiilaq',
#  'upernavik',
#  'namatanai',
#  'saint-philippe',
# ...

# %%
for i, item in enumerate(cities):
    print (i, item)
# Out:
# 0 port elizabeth
# 1 lagos
# 2 severo-kurilsk
# 3 kyabe
# 4 busselton
# 5 nemuro
# 6 iqaluit
# 7 ixtapa
# 8 puerto ayora
# 9 bisert
# 10 avarua
# 11 cabanas
# 12 vaitupu
# 13 buraydah
# 14 hermanus
# 15 butaritari
# 16 dallas
# 17 beihai
# 18 khatanga
# 19 te anau
# 20 charlestown
# 21 haines junction
# 22 itarema
# 23 luderitz
# 24 japura
# 25 leningradskiy
# 26 lebu
# 27 nikolskoye
# 28 ponta do sol
# 29 ushuaia
# 30 laizhou
# 31 svetlaya
# 32 san patricio
# 33 san joaquin
# 34 lasa
# 35 kupang
# 36 margate
# 37 kodiak
# 38 necocli
# 39 rikitea
# 40 kavieng
# 41 katihar
# 42 finnsnes
# 43 tsihombe
# 44 lompoc
# 45 kudahuvadhoo
# 46 khuzdar
# 47 faanui
# 48 mataura
# 49 san policarpo
# 50 punta arenas
# 51 sangar
# 52 east london
# 53 tuktoyaktuk
# 54 yellowknife
# 55 bambous virieux
# 56 samusu
# 57 jamestown
# 58 kimbe
# 59 georgetown
# 60 tasiilaq
# 61 upernavik
# 62 namatanai
# 63 saint-philippe
# 64 albany
# 65 guerrero negro
# 66 illoqqortoormiut
# 67 port macquarie
# ...

# %%
# Run an API request for each of the cities.
# Loop through all the cities in the list.
# The OpenWeatherMap API only allows 60 calls for per minute on their free tier, so 
# pausing our program for one minute after each set of 50 will prevent time-out errors


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    # at the end of the code - it concatenate city - but replaces any spaces with "+"
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City: " +city+ " not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | lagos
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | kyabe
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | nemuro
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | ixtapa
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | bisert
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | cabanas
# Processing Record 13 of Set 1 | vaitupu
# City: vaitupu not found. Skipping...
# Processing Record 14 of Set 1 | buraydah
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | dallas
# Processing Record 18 of Set 1 | beihai
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | te anau
# Processing Record 21 of Set 1 | charlestown
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     64.09        99         100
# 1           Lagos   6.5833    3.7500     81.36        83         100
# 2  Severo-Kurilsk  50.6789  156.1250     30.15        67          99
# 3           Kyabe   9.4515   18.9449     84.02        40          83
# 4       Busselton -33.6500  115.3333     72.00        41          36
# 5          Nemuro  43.3236  145.5750     32.63        83          14
# 6         Iqaluit  63.7506  -68.5145      4.37        92         100
# 7          Ixtapa  20.7000 -105.2000     72.63        68           0
# 8    Puerto Ayora  -0.7393  -90.3518     78.76        80         100
# 9          Bisert  56.8617   59.0523     29.07        89          99
#
#    Wind Speed Country                 Date
# 0       10.36      ZA  2022-03-25 01:11:07
# 1        6.22      NG  2022-03-25 01:07:29
# 2        9.95      RU  2022-03-25 01:11:08
# ...

# %%
new_column_order = ["City", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Country",
                   "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                City                 Date      Lat       Lng  Max Temp  \
# 0    Port Elizabeth  2022-03-25 01:11:07 -33.9180   25.5701     64.09
# 1             Lagos  2022-03-25 01:07:29   6.5833    3.7500     81.36
# 2    Severo-Kurilsk  2022-03-25 01:11:08  50.6789  156.1250     30.15
# 3             Kyabe  2022-03-25 01:11:08   9.4515   18.9449     84.02
# 4         Busselton  2022-03-25 01:11:09 -33.6500  115.3333     72.00
# ..              ...                  ...      ...       ...       ...
# 572       Sanmenxia  2022-03-25 01:27:14  34.7747  111.1814     56.52
# 573         Aljezur  2022-03-25 01:27:15  37.3191   -8.8033     51.26
# 574           Rocha  2022-03-25 01:27:15 -34.4833  -54.3333     57.31
# 575       Martapura  2022-03-25 01:27:17  -3.4167  114.8500     77.09
# 576   Santo Augusto  2022-03-25 01:27:18 -27.8508  -53.7772     65.57
#
#      Humidity Country  Cloudiness  Wind Speed
# 0          99      ZA         100       10.36
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
